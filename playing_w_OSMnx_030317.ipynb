# %%
import matplotlib.pylab as plt
import osmnx as ox
import numpy as np
import networkx
import os
import shapefile

np.random.seed(222)

# %matplotlib inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['plt']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
G = ox.graph_from_point((40.69, -73.98), distance=(5280.0/4), network_type='drive')
ox.plot_graph(G)
# Out:
# (<matplotlib.figure.Figure at 0x123b29550>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x122e3c710>)

# %%
F = ox.graph_from_point((40.69, -73.98), distance=(500), network_type='drive')
ox.plot_graph(F)
# Out:
# (<matplotlib.figure.Figure at 0x119e95b50>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x11be1b910>)

# %%
networkx.write_shp(F, '...')

# %%
H = ox.graph_from_point((40.69, -73.98), distance=(5280.0), network_type='drive')
ox.plot_graph(H)
# Out:
# (<matplotlib.figure.Figure at 0x120aad0d0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x120aad890>)

# %%
intersections = [key for key, value in G.graph['streets_per_node'].items() if value>1]
nc = ['r' if node in intersections else 'none' for node in G.nodes()]
ox.plot_graph(G, node_color=nc)
# Out:
# (<matplotlib.figure.Figure at 0x123ade610>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x123adec10>)

# %%
intersections = [key for key, value in F.graph['streets_per_node'].items() if value>1]
nc = ['r' if node in intersections else 'none' for node in F.nodes()]
ox.plot_graph(F, node_color=nc)
# Out:
# (<matplotlib.figure.Figure at 0x1230fa110>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x10a888850>)

# %%
NYC = ox.gdf_from_place('New York, NY')
ox.plot_shape(ox.project_gdf(NYC))
# Out:
# (<matplotlib.figure.Figure at 0x1230f5950>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1287a9fd0>)

# %%
NYC_roads = ox.graph_from_place('New York, NY', network_type='drive')
ox.plot_graph(NYC_roads)
# Out:
# (<matplotlib.figure.Figure at 0x11c5a4690>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x11c5a4e10>)

# %%
os.getcwd()
# Out:
# '/Users/geoffperrin/Desktop/CUSP/GRA/NYPD/ipython_notebooks'

# %%
networkx.write_shp(NYC_roads, '/Users/geoffperrin/Desktop/CUSP/GRA/NYPD/ipython_notebooks')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-42f4c4926aa1> in <module>()
# ----> 1 networkx.write_shp(NYC_roads, '/Users/geoffperrin/Desktop/CUSP/GRA/NYPD/ipython_notebooks')
#
# NameError: name 'networkx' is not defined

# %%
len(unique(intersections))

# %%
basic_stats = ox.basic_stats(G)
print basic_stats

# %%
basic_stats['street_length_total'] / basic_stats['count_intersections']
